# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# _Authors: Dave Yerrington (SF)_
#
# ---

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
rockfile = "./datasets/rock.csv"

# %%
# Load the data.
df = pd.read_csv(rockfile)

# %%
# Look at the information regarding its columns.
df.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
# Change the column names when loading the '.csv':
#df.dtypes
df.shape
#df.info


df.columns = ['Song Clean','ARTIST','yr_Released','Combo','First Aired','Year Aired','Played Count','F*G']

df.shape
# Out:
# (2230, 8)

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
#Song Clean	ARTIST CLEAN	Release Year	COMBINED	First?	Year?	PlayCount	F*G
df_rock = df.rename(columns={'Song Clean': 'Song'}, index={'ONE': 'one'})
df_rock.dtypes
# Out:
# Song            object
# ARTIST          object
# yr_Released     object
# Combo           object
# First Aired      int64
# Year Aired       int64
# Played Count     int64
# F*G              int64
# dtype: object

# %% [markdown]
# #### 2.C Reassigning the `.columns` attribute of a DataFrame.
#
# You can also just reassign the `.columns` attribute to a list of strings containing the new column names.
#
# The only caveat with reassigning `.columns` is that you have to reassign all of the column names at once. You can't partially replace a value by working on `.columns` directly. You have to reassign `.columns` with a list of equal length.

# %%
# Replace the column names by reassigning the `.columns` attribute.

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
# Show records where df['release'] is null

df_rock['yr_Released'].isnull()

#null_columns=df.columns[df.isnull().any()]
#print(df[df["Year Released"].isnull()][null_columns])
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 2225     True
# 2226    False
# 2227    False
# 2228    False
# 2229    False
# Name: yr_Released, Length: 2230, dtype: bool

# %% [markdown]
# ### 4. Update slices of your DataFrame based on mask selection/slices.
#
# In many scenarios, we want to upate values in our DataFrame according to criteria. Let's say we wanted to set all of the null values in `release` to 0.
#
# With newer versions of `pandas`, in order to manipulate data in the original DataFrame, we have to use `.loc` while performing reassignment using a mask and an index.
#
# For example, the following won't always work:
# ```python
# df[row_mask]['column_name'] = new_value
# ```
#
# The best way to accomplish the same task is:
# ```python
# df.loc[row_mask, 'column_name'] = new_value
# ```
#
# For multiple column assignment, you would use:
# ```python
# df.loc[row_mask, ['col_1', 'col_2', 'col_3']] = new_value
# ```
#
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
# Replace release nulls with 0

df_rock['yr_Released'].fillna(0, inplace=True)
#df_rock.head()

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
# A:
df_rock.isnull().sum()
# Out:
# Song            0
# ARTIST          0
# yr_Released     0
# Combo           0
# First Aired     0
# Year Aired      0
# Played Count    0
# F*G             0
# dtype: int64

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:

df_rock.dtypes
# Out:
# Song            object
# ARTIST          object
# yr_Released     object
# Combo           object
# First Aired      int64
# Year Aired       int64
# Played Count     int64
# F*G              int64
# dtype: object

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
# A:

df_rock.yr_Released.unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'SONGFACTS.COM', '1963',
#        '1961'], dtype=object)

# %%
#df_rock.yr_Released.replace('SONGFACTS.COM',0)

df_rock.yr_Released = df_rock.yr_Released.replace({'SONGFACTS.COM': 'NaN'})

# %%
df_rock.yr_Released.unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'NaN', '1963', '1961'],
#       dtype=object)

# %%
df_rock.yr_Released = df_rock.yr_Released.replace({'NaN':0})

# %%
df_rock.dtypes
# Out:
# Song            object
# ARTIST          object
# yr_Released     object
# Combo           object
# First Aired      int64
# Year Aired       int64
# Played Count     int64
# F*G              int64
# dtype: object

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
# A:

# %%
convert_dict = {'yr_Released': "int64"
               } 
  
df_rock = df_rock.astype(convert_dict) 
df_rock.dtypes
# Out:
# Song            object
# ARTIST          object
# yr_Released      int64
# Combo           object
# First Aired      int64
# Year Aired       int64
# Played Count     int64
# F*G              int64
# dtype: object

# %% [markdown]
# #### 6.C. Clean up the data. Normally we may replace the offending data with null np.nan values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
# A:
df_rock.dtypes

df_rock.head()
# Out:
#                      Song       ARTIST  yr_Released  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special            0
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                    Combo  First Aired  Year Aired  \
# 0        Caught Up in You by .38 Special            1           1
# 1            Fantasy Girl by .38 Special            1           0
# 2         Hold On Loosely by .38 Special            1           1
# 3  Rockin' Into the Night by .38 Special            1           1
# 4              Art For Arts Sake by 10cc            1           1
#
#    Played Count  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
df_rock.yr_Released.describe
# Out:
# <bound method NDFrame.describe of 0       1982
# 1          0
# 2       1981
# 3       1980
# 4       1975
#         ...
# 2225       0
# 2226    1981
# 2227    1975
# 2228    1983
# 2229    1973
# Name: yr_Released, Length: 2230, dtype: int64>

# %%
# A:
df_rock.sort_values(by = ['yr_Released'] , ascending= False)
# Out:
#                       Song             ARTIST  yr_Released  \
# 331    Take Out The Gunman           Chevelle         2014
# 40          Dog On A Leash       Adelitas Way         2014
# 1282        Lightning Bolt          Pearl Jam         2013
# 1284                Sirens          Pearl Jam         2013
# 1462        Doom And Gloom     Rolling Stones         2012
# ...                    ...                ...          ...
# 844       Shakedown Cruise       Jay Ferguson            0
# 1615  Living in the U.S.A.  Steve Miller Band            0
# 1616         Mercury Blues  Steve Miller Band            0
# 843             Summertime       Janis Joplin            0
# 252       Raise Your Hands           Bon Jovi            0
#
#                                           Combo  First Aired  Year Aired  \
# 331             Take Out The Gunman by Chevelle            1           1
# 40               Dog On A Leash by Adelitas Way            1           1
# 1282                Lightning Bolt by Pearl Jam            1           1
# 1284                        Sirens by Pearl Jam            1           1
# 1462           Doom And Gloom by Rolling Stones            1           1
# ...                                         ...          ...         ...
# 844            Shakedown Cruise by Jay Ferguson            1           0
# 1615  Living in the U.S.A. by Steve Miller Band            1           0
# 1616         Mercury Blues by Steve Miller Band            1           0
# 843                  Summertime by Janis Joplin            1           0
# 252                Raise Your Hands by Bon Jovi            1           0
#
#       Played Count  F*G
# 331              4    4
# 40               4    4
# 1282             4    4
# 1284             3    3
# 1462             1    1
# ...            ...  ...
# 844              1    0
# 1615             1    0
# 1616             1    0
# 843              3    0
# 252              1    0
#
# [2230 rows x 8 columns]

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %%
# A:
df_rock.yr_Released = df_rock.yr_Released.replace({1071: 1971})

# %%
df_rock.yr_Released.unique()
# Out:
# array([1982,    0, 1981, 1980, 1975, 2000, 2002, 1992, 1985, 1993, 1976,
#        1995, 1979, 1984, 1977, 1990, 1986, 1974, 2014, 1987, 1973, 2001,
#        1989, 1997, 1971, 1972, 1994, 1970, 1966, 1965, 1983, 1955, 1978,
#        1969, 1999, 1968, 1988, 1962, 2007, 1967, 1958, 1996, 1991, 2005,
#        2011, 2004, 2012, 2003, 1998, 2008, 1964, 2013, 2006, 1963, 1961])

# %% [markdown]
# _Looking at the DataFrame that contains the year 1071, we can see that the year was probably corrupted and should be replaced with something else if possible._

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# A:
df = pd.DataFrame(df_rock) 
df_new = df[['Song', 'ARTIST', 'yr_Released']].copy()
for i, j in df_new.iterrows(): 
    print(i, j) 
    print()
# Out:
# 0 Song           Caught Up in You
# ARTIST              .38 Special
# yr_Released                1982
# Name: 0, dtype: object
#
# 1 Song           Fantasy Girl
# ARTIST          .38 Special
# yr_Released               0
# Name: 1, dtype: object
#
# 2 Song           Hold On Loosely
# ARTIST             .38 Special
# yr_Released               1981
# Name: 2, dtype: object
#
# 3 Song           Rockin' Into the Night
# ARTIST                    .38 Special
# yr_Released                      1980
# Name: 3, dtype: object
#
# 4 Song           Art For Arts Sake
# ARTIST                      10cc
# yr_Released                 1975
# Name: 4, dtype: object
#
# 5 Song             Kryptonite
# ARTIST         3 Doors Down
# yr_Released            2000
# Name: 5, dtype: object
#
# 6 Song                  Loser
# ARTIST         3 Doors Down
# yr_Released            2000
# Name: 6, dtype: object
#
# 7 Song           When I'm Gone
# ARTIST          3 Doors Down
# yr_Released             2002
# Name: 7, dtype: object
#
# 8 Song              What's Up?
# ARTIST         4 Non Blondes
# yr_Released             1992
# Name: 8, dtype: object
#
# 9 Song           Take On Me
# ARTIST               a-ha
# yr_Released          1985
# Name: 9, dtype: object
#
# 10 Song           Baby, Please Don't Go
# ARTIST                         AC/DC
# yr_Released                        0
# Name: 10, dtype: object
#
# 11 Song           Back In Black
# ARTIST                 AC/DC
# yr_Released             1980
# Name: 11, dtype: object
#
# 12 Song           Big Gun
# ARTIST           AC/DC
# yr_Released       1993
# Name: 12, dtype: object
#
# 13 Song           CAN'T STOP ROCK'N'ROLL
# ARTIST                          AC/DC
# yr_Released                         0
# Name: 13, dtype: object
#
# 14 Song           Dirty Deeds Done Dirt Cheap
# ARTIST                               AC/DC
# yr_Released                           1976
# Name: 14, dtype: object
#
# 15 Song           For Those About To Rock
# ARTIST                           AC/DC
# yr_Released                       1981
# Name: 15, dtype: object
#
# 16 Song           Girls Got Rhythm
# ARTIST                    AC/DC
# yr_Released                   0
# Name: 16, dtype: object
#
# 17 Song           Hard As A Rock
# ARTIST                  AC/DC
# yr_Released              1995
# Name: 17, dtype: object
#
# 18 Song           Have a Drink On Me
# ARTIST                      AC/DC
# yr_Released                  1980
# Name: 18, dtype: object
#
# 19 Song           Hells Bells
# ARTIST               AC/DC
# yr_Released           1980
# Name: 19, dtype: object
#
# 20 Song           Highway To Hell
# ARTIST                   AC/DC
# yr_Released               1979
# Name: 20, dtype: object
#
# 21 Song           It's A Long Way To The Top
# ARTIST                              AC/DC
# yr_Released                          1975
# Name: 21, dtype: object
#
# 22 Song           Jailbreak
# ARTIST             AC/DC
# yr_Released         1984
# Name: 22, dtype: object
#
# 23 Song           Let There Be Rock
# ARTIST                     AC/DC
# yr_Released                 1977
# Name: 23, dtype: object
#
# 24 Song           Let's Get It Up
# ARTIST                   AC/DC
# yr_Released                  0
# Name: 24, dtype: object
#
# 25 Song           Live Wire
# ARTIST             AC/DC
# yr_Released            0
# Name: 25, dtype: object
#
# 26 Song           Moneytalks
# ARTIST              AC/DC
# yr_Released             0
# Name: 26, dtype: object
#
# 27 Song           Night Prowler
# ARTIST                 AC/DC
# yr_Released             1979
# Name: 27, dtype: object
#
# 28 Song           Rock and Roll Ain't Noise Pollution
# ARTIST                                       AC/DC
# yr_Released                                   1980
# Name: 28, dtype: object
#
# 29 Song           Shoot To Thrill
# ARTIST                   AC/DC
# yr_Released                  0
# Name: 29, dtype: object
#
# 30 Song           Shot Down In Flames
# ARTIST                       AC/DC
# yr_Released                   1979
# Name: 30, dtype: object
#
# 31 Song           Sin City
# ARTIST            AC/DC
# yr_Released           0
# Name: 31, dtype: object
#
# 32 Song           T.N.T.
# ARTIST          AC/DC
# yr_Released      1975
# Name: 32, dtype: object
#
# 33 Song           Thunderstruck
# ARTIST                 AC/DC
# yr_Released             1990
# Name: 33, dtype: object
#
# 34 Song           Touch Too Much
# ARTIST                  AC/DC
# yr_Released              1979
# Name: 34, dtype: object
#
# 35 Song           What Do You Do For Money Honey
# ARTIST                                  AC/DC
# yr_Released                                 0
# Name: 35, dtype: object
#
# 36 Song           Who Made Who
# ARTIST                AC/DC
# yr_Released            1986
# Name: 36, dtype: object
#
# 37 Song           Whole Lotta Rosie
# ARTIST                     AC/DC
# yr_Released                 1977
# Name: 37, dtype: object
#
# 38 Song           You Shook Me All Night Long
# ARTIST                               AC/DC
# yr_Released                           1980
# Name: 38, dtype: object
#
# 39 Song           How Long
# ARTIST              Ace
# yr_Released        1974
# Name: 39, dtype: object
#
# 40 Song           Dog On A Leash
# ARTIST           Adelitas Way
# yr_Released              2014
# Name: 40, dtype: object
#
# 41 Song               Angel
# ARTIST         Aerosmith
# yr_Released         1987
# Name: 41, dtype: object
#
# 42 Song           Baby, Please Don't Go
# ARTIST                     Aerosmith
# yr_Released                        0
# Name: 42, dtype: object
#
# 43 Song           Back in the Saddle
# ARTIST                  Aerosmith
# yr_Released                  1976
# Name: 43, dtype: object
#
# 44 Song           Big Ten Inch
# ARTIST            Aerosmith
# yr_Released            1975
# Name: 44, dtype: object
#
# 45 Song           Come Together
# ARTIST             Aerosmith
# yr_Released                0
# Name: 45, dtype: object
#
# 46 Song               Crazy
# ARTIST         Aerosmith
# yr_Released         1993
# Name: 46, dtype: object
#
# 47 Song              Cryin'
# ARTIST         Aerosmith
# yr_Released         1993
# Name: 47, dtype: object
#
# 48 Song           Draw The Line
# ARTIST             Aerosmith
# yr_Released             1977
# Name: 48, dtype: object
#
# 49 Song            Dream On
# ARTIST         Aerosmith
# yr_Released         1973
# Name: 49, dtype: object
#
# 50 Song           Dude (Looks Like a Lady)
# ARTIST                        Aerosmith
# yr_Released                        1987
# Name: 50, dtype: object
#
# 51 Song               Jaded
# ARTIST         Aerosmith
# yr_Released         2001
# Name: 51, dtype: object
#
# 52 Song           Janie's Got A Gun
# ARTIST                 Aerosmith
# yr_Released                 1989
# Name: 52, dtype: object
#
# 53 Song           Kings and Queens
# ARTIST                Aerosmith
# yr_Released                   0
# Name: 53, dtype: object
#
# 54 Song           Last Child
# ARTIST          Aerosmith
# yr_Released          1976
# Name: 54, dtype: object
#
# 55 Song           Let the Music Do the Talking
# ARTIST                            Aerosmith
# yr_Released                            1985
# Name: 55, dtype: object
#
# 56 Song           Livin' On The Edge
# ARTIST                  Aerosmith
# yr_Released                  1993
# Name: 56, dtype: object
#
# 57 Song           Love In An Elevator
# ARTIST                   Aerosmith
# yr_Released                   1989
# Name: 57, dtype: object
#
# 58 Song            Mama Kin
# ARTIST         Aerosmith
# yr_Released         1973
# Name: 58, dtype: object
#
# 59 Song           No More No More
# ARTIST               Aerosmith
# yr_Released               1975
# Name: 59, dtype: object
#
# 60 Song           One Way Street
# ARTIST              Aerosmith
# yr_Released                 0
# Name: 60, dtype: object
#
# 61 Song                Pink
# ARTIST         Aerosmith
# yr_Released         1997
# Name: 61, dtype: object
#
# 62 Song            Rag Doll
# ARTIST         Aerosmith
# yr_Released         1987
# Name: 62, dtype: object
#
# 63 Song           Same Old Song and Dance
# ARTIST                       Aerosmith
# yr_Released                       1974
# Name: 63, dtype: object
#
# 64 Song           Seasons of Wither
# ARTIST                 Aerosmith
# yr_Released                 1974
# Name: 64, dtype: object
#
# 65 Song           Sweet Emotion
# ARTIST             Aerosmith
# yr_Released             1975
# Name: 65, dtype: object
#
# 66 Song           The Other Side
# ARTIST              Aerosmith
# yr_Released                 0
# Name: 66, dtype: object
#
# 67 Song           Toys in the Attic
# ARTIST                 Aerosmith
# yr_Released                 1975
# Name: 67, dtype: object
#
# 68 Song           Train Kept A-Rollin'
# ARTIST                    Aerosmith
# yr_Released                    1974
# Name: 68, dtype: object
#
# 69 Song           Walk This Way
# ARTIST             Aerosmith
# yr_Released             1975
# Name: 69, dtype: object
#
# 70 Song           What It Takes
# ARTIST             Aerosmith
# yr_Released             1989
# Name: 70, dtype: object
#
# 71 Song           You See Me Crying
# ARTIST                 Aerosmith
# yr_Released                    0
# Name: 71, dtype: object
#
# 72 Song           Hand In My Pocket
# ARTIST         Alanis Morissette
# yr_Released                 1995
# Name: 72, dtype: object
#
# 73 Song             You Oughta Know
# ARTIST         Alanis Morissette
# yr_Released                 1995
# Name: 73, dtype: object
#
# 74 Song            Black Velvet
# ARTIST         Alannah Myles
# yr_Released             1989
# Name: 74, dtype: object
#
# 75 Song             Fantasy
# ARTIST         Aldo Nova
# yr_Released            0
# Name: 75, dtype: object
#
# 76 Song            BE MY LOVER
# ARTIST         Alice Cooper
# yr_Released               0
# Name: 76, dtype: object
#
# 77 Song           Billion Dollar Babies
# ARTIST                  Alice Cooper
# yr_Released                     1973
# Name: 77, dtype: object
#
# 78 Song               Eighteen
# ARTIST         Alice Cooper
# yr_Released            1971
# Name: 78, dtype: object
#
# 79 Song                Elected
# ARTIST         Alice Cooper
# yr_Released            1973
# Name: 79, dtype: object
#
# 80 Song           House Of Fire
# ARTIST          Alice Cooper
# yr_Released                0
# Name: 80, dtype: object
#
# 81 Song           I'm Eighteen
# ARTIST         Alice Cooper
# yr_Released            1971
# Name: 81, dtype: object
#
# 82 Song           No More Mr. Nice Guy
# ARTIST                 Alice Cooper
# yr_Released                    1973
# Name: 82, dtype: object
#
# 83 Song           School's Out
# ARTIST         Alice Cooper
# yr_Released            1972
# Name: 83, dtype: object
#
# 84 Song           Under My Wheels
# ARTIST            Alice Cooper
# yr_Released               1971
# Name: 84, dtype: object
#
# 85 Song           Welcome To My Nightmare
# ARTIST                    Alice Cooper
# yr_Released                       1975
# Name: 85, dtype: object
#
# 86 Song            Down in a Hole
# ARTIST         Alice In Chains
# yr_Released               1992
# Name: 86, dtype: object
#
# 87 Song            Man In The Box
# ARTIST         Alice In Chains
# yr_Released               1990
# Name: 87, dtype: object
#
# 88 Song                No Excuses
# ARTIST         Alice In Chains
# yr_Released               1994
# Name: 88, dtype: object
#
# 89 Song                   Rooster
# ARTIST         Alice In Chains
# yr_Released               1992
# Name: 89, dtype: object
#
# 90 Song                Them Bones
# ARTIST         Alice In Chains
# yr_Released               1992
# Name: 90, dtype: object
#
# 91 Song                    Would?
# ARTIST         Alice In Chains
# yr_Released               1992
# Name: 91, dtype: object
#
# 92 Song           Ain't Wastin' Time No More
# ARTIST               Allman Brothers Band
# yr_Released                          1972
# Name: 92, dtype: object
#
# 93 Song                       Blue Sky
# ARTIST         Allman Brothers Band
# yr_Released                    1972
# Name: 93, dtype: object
#
# 94 Song                 Good Clean Fun
# ARTIST         Allman Brothers Band
# yr_Released                    1990
# Name: 94, dtype: object
#
# 95 Song           In Memory Of Elizabeth Reed
# ARTIST                Allman Brothers Band
# yr_Released                           1970
# Name: 95, dtype: object
#
# 96 Song                        Jessica
# ARTIST         Allman Brothers Band
# yr_Released                    1973
# Name: 96, dtype: object
#
# 97 Song                        Melissa
# ARTIST         Allman Brothers Band
# yr_Released                    1972
# Name: 97, dtype: object
#
# 98 Song                 Midnight Rider
# ARTIST         Allman Brothers Band
# yr_Released                    1970
# Name: 98, dtype: object
#
# 99 Song             No One to Run With
# ARTIST         Allman Brothers Band
# yr_Released                    1994
# Name: 99, dtype: object
#
# 100 Song                    One Way Out
# ARTIST         Allman Brothers Band
# yr_Released                       0
# Name: 100, dtype: object
#
# 101 Song                   Ramblin' Man
# ARTIST         Allman Brothers Band
# yr_Released                    1973
# Name: 101, dtype: object
#
# 102 Song                     Southbound
# ARTIST         Allman Brothers Band
# yr_Released                       0
# Name: 102, dtype: object
#
# 103 Song               Statesboro Blues
# ARTIST         Allman Brothers Band
# yr_Released                    1971
# Name: 103, dtype: object
#
# 104 Song                  Whippin' Post
# ARTIST         Allman Brothers Band
# yr_Released                       0
# Name: 104, dtype: object
#
# 105 Song           A Horse With No Name
# ARTIST                      America
# yr_Released                    1972
# Name: 105, dtype: object
#
# 106 Song           Sister Golden Hair
# ARTIST                    America
# yr_Released                  1975
# Name: 106, dtype: object
#
# 107 Song           Ventura Highway
# ARTIST                 America
# yr_Released               1972
# Name: 107, dtype: object
#
# 108 Song           Don't Bring Me Down
# ARTIST                  Animals II
# yr_Released                   1966
# Name: 108, dtype: object
#
# 109 Song           Don't Let Me Be Misunderstood
# ARTIST                            Animals II
# yr_Released                             1965
# Name: 109, dtype: object
#
# 110 Song           Immigrant Song
# ARTIST             Ann Wilson
# yr_Released                 0
# Name: 110, dtype: object
#
# 111 Song               Roller
# ARTIST         April Wine
# yr_Released             0
# Name: 111, dtype: object
#
# 112 Song           Hold Your Head Up
# ARTIST                    Argent
# yr_Released                 1972
# Name: 112, dtype: object
#
# 113 Song           Coming into Los Angeles
# ARTIST                    Arlo Guthrie
# yr_Released                          0
# Name: 113, dtype: object
#
# 114 Song                 Wayside
# ARTIST         Artful Dodger
# yr_Released                0
# Name: 114, dtype: object
#
# 115 Song           Heat of the Moment
# ARTIST                       Asia
# yr_Released                  1982
# Name: 115, dtype: object
#
# 116 Song           Only Time Will Tell
# ARTIST                        Asia
# yr_Released                   1982
# Name: 116, dtype: object
#
# 117 Song                      So Into You
# ARTIST         Atlanta Rhythm Section
# yr_Released                      1976
# Name: 117, dtype: object
#
# 118 Song                           Spooky
# ARTIST         Atlanta Rhythm Section
# yr_Released                         0
# Name: 118, dtype: object
#
# 119 Song           Like a Stone
# ARTIST           Audioslave
# yr_Released            2002
# Name: 119, dtype: object
#
# 120 Song           Blondes In Black Cars
# ARTIST                     Autograph
# yr_Released                        0
# Name: 120, dtype: object
#
# 121 Song           Turn Up the Radio
# ARTIST                 Autograph
# yr_Released                 1984
# Name: 121, dtype: object
#
# 122 Song           Rock And Roll Party In The Streets
# ARTIST                                        Axe
# yr_Released                                     0
# Name: 122, dtype: object
#
# 123 Song                        Let It Ride
# ARTIST         Bachman-Turner Overdrive
# yr_Released                        1973
# Name: 123, dtype: object
#
# 124 Song           Roll On Down The Highway
# ARTIST         Bachman-Turner Overdrive
# yr_Released                           0
# Name: 124, dtype: object
#
# 125 Song            Takin' Care Of Business
# ARTIST         Bachman-Turner Overdrive
# yr_Released                        1973
# Name: 125, dtype: object
#
# 126 Song           You Ain't Seen Nothin' Yet
# ARTIST           Bachman-Turner Overdrive
# yr_Released                          1974
# Name: 126, dtype: object
#
# 127 Song           Bad Company
# ARTIST         Bad Company
# yr_Released           1974
# Name: 127, dtype: object
#
# 128 Song           Burnin' Sky
# ARTIST         Bad Company
# yr_Released           1977
# Name: 128, dtype: object
#
# 129 Song           Can't Get Enough
# ARTIST              Bad Company
# yr_Released                1974
# Name: 129, dtype: object
#
# 130 Song           Feel Like Makin' Love
# ARTIST                   Bad Company
# yr_Released                        0
# Name: 130, dtype: object
#
# 131 Song           Gone Gone Gone
# ARTIST            Bad Company
# yr_Released                 0
# Name: 131, dtype: object
#
# 132 Song           Good Lovin' Gone Bad
# ARTIST                  Bad Company
# yr_Released                       0
# Name: 132, dtype: object
#
# 133 Song             Movin' On
# ARTIST         Bad Company
# yr_Released              0
# Name: 133, dtype: object
#
# 134 Song           Ready For Love
# ARTIST            Bad Company
# yr_Released                 0
# Name: 134, dtype: object
#
# 135 Song           Rock 'n' Roll Fantasy
# ARTIST                   Bad Company
# yr_Released                        0
# Name: 135, dtype: object
#
# 136 Song           Rock Steady
# ARTIST         Bad Company
# yr_Released              0
# Name: 136, dtype: object
#
# 137 Song           Run With The Pack
# ARTIST               Bad Company
# yr_Released                    0
# Name: 137, dtype: object
#
# 138 Song               Seagull
# ARTIST         Bad Company
# yr_Released           1974
# Name: 138, dtype: object
#
# 139 Song           Shooting Star
# ARTIST           Bad Company
# yr_Released             1975
# Name: 139, dtype: object
#
# 140 Song           Silver, Blue And Gold
# ARTIST                   Bad Company
# yr_Released                        0
# Name: 140, dtype: object
#
# 141 Song           When I See You Smile
# ARTIST                  Bad English
# yr_Released                    1989
# Name: 141, dtype: object
#
# 142 Song           No Matter What
# ARTIST              Badfinger
# yr_Released              1970
# Name: 142, dtype: object
#
# 143 Song           Walks Like A Woman
# ARTIST                Baton Rouge
# yr_Released                     0
# Name: 143, dtype: object
#
# 144 Song           (You Gotta) Fight for Your Right (To Party)
# ARTIST                                        Beastie Boys
# yr_Released                                           1986
# Name: 144, dtype: object
#
# 145 Song           No Sleep Till Brooklyn
# ARTIST                   Beastie Boys
# yr_Released                      1986
# Name: 145, dtype: object
#
# 146 Song           Loser
# ARTIST          Beck
# yr_Released     1994
# Name: 146, dtype: object
#
# 147 Song           In a Big Country
# ARTIST              Big Country
# yr_Released                1983
# Name: 147, dtype: object
#
# 148 Song           Rock Around the Clock
# ARTIST                    Bill Haley
# yr_Released                     1955
# Name: 148, dtype: object
#
# 149 Song           AIN'T NO SUNSHINE
# ARTIST              Bill Withers
# yr_Released                 1971
# Name: 149, dtype: object
#
# 150 Song           Cradle of Love
# ARTIST             Billy Idol
# yr_Released              1990
# Name: 150, dtype: object
#
# 151 Song           Dancing With Myself
# ARTIST                  Billy Idol
# yr_Released                   1980
# Name: 151, dtype: object
#
# 152 Song           Eyes Without a Face
# ARTIST                  Billy Idol
# yr_Released                   1984
# Name: 152, dtype: object
#
# 153 Song            Mony Mony
# ARTIST         Billy Idol
# yr_Released             0
# Name: 153, dtype: object
#
# 154 Song           Rebel Yell
# ARTIST         Billy Idol
# yr_Released          1984
# Name: 154, dtype: object
#
# 155 Song           White Wedding
# ARTIST            Billy Idol
# yr_Released             1982
# Name: 155, dtype: object
#
# 156 Song            Allentown
# ARTIST         Billy Joel
# yr_Released          1982
# Name: 156, dtype: object
#
# 157 Song             Big Shot
# ARTIST         Billy Joel
# yr_Released          1978
# Name: 157, dtype: object
#
# 158 Song           Captain Jack
# ARTIST           Billy Joel
# yr_Released            1973
# Name: 158, dtype: object
#
# 159 Song           Don't Ask Me Why
# ARTIST               Billy Joel
# yr_Released                   0
# Name: 159, dtype: object
#
# 160 Song           Goodnight Saigon
# ARTIST               Billy Joel
# yr_Released                1983
# Name: 160, dtype: object
#
# 161 Song           It's Still Rock And Roll To Me
# ARTIST                             Billy Joel
# yr_Released                              1980
# Name: 161, dtype: object
#
# 162 Song           Miami 2017 {seen The Lights Go Out On Broadway...
# ARTIST                                                Billy Joel
# yr_Released                                                 1976
# Name: 162, dtype: object
#
# 163 Song           Movin' Out (Anthony's Song)
# ARTIST                          Billy Joel
# yr_Released                           1977
# Name: 163, dtype: object
#
# 164 Song              My Life
# ARTIST         Billy Joel
# yr_Released          1978
# Name: 164, dtype: object
#
# 165 Song           New York State Of Mind
# ARTIST                     Billy Joel
# yr_Released                      1976
# Name: 165, dtype: object
#
# 166 Song           Only The Good Die Young
# ARTIST                      Billy Joel
# yr_Released                       1977
# Name: 166, dtype: object
#
# 167 Song            Piano Man
# ARTIST         Billy Joel
# yr_Released          1973
# Name: 167, dtype: object
#
# 168 Song           Prelude/angry Young Man
# ARTIST                      Billy Joel
# yr_Released                          0
# Name: 168, dtype: object
#
# 169 Song           Scenes From An Italian Restaurant
# ARTIST                                Billy Joel
# yr_Released                                 1977
# Name: 169, dtype: object
#
# 170 Song           SHE'S ALWAYS A WOMAN
# ARTIST                   Billy Joel
# yr_Released                    1977
# Name: 170, dtype: object
#
# 171 Song           Sometimes A Fantasy
# ARTIST                  Billy Joel
# yr_Released                   1980
# Name: 171, dtype: object
#
# 172 Song           The Ballad Of Billy The Kid
# ARTIST                          Billy Joel
# yr_Released                           1973
# Name: 172, dtype: object
#
# 173 Song           The Stranger
# ARTIST           Billy Joel
# yr_Released            1977
# Name: 173, dtype: object
#
# 174 Song           You May Be Right
# ARTIST               Billy Joel
# yr_Released                1980
# Name: 174, dtype: object
#
# 175 Song           Baby Come Back
# ARTIST           Billy Rankin
# yr_Released                 0
# Name: 175, dtype: object
#
# 176 Song           Everybody Wants You
# ARTIST                Billy Squier
# yr_Released                      0
# Name: 176, dtype: object
#
# 177 Song            In the Dark
# ARTIST         Billy Squier
# yr_Released               0
# Name: 177, dtype: object
#
# 178 Song           Lonely Is the Night
# ARTIST                Billy Squier
# yr_Released                   1981
# Name: 178, dtype: object
#
# 179 Song           My Kinda Lover
# ARTIST           Billy Squier
# yr_Released                 0
# Name: 179, dtype: object
#
# 180 Song           Rock Me Tonight
# ARTIST            Billy Squier
# yr_Released               1984
# Name: 180, dtype: object
#
# 181 Song           She's a Runner
# ARTIST           Billy Squier
# yr_Released                 0
# Name: 181, dtype: object
#
# 182 Song             The Stroke
# ARTIST         Billy Squier
# yr_Released            1981
# Name: 182, dtype: object
#
# 183 Song           Children Of The Sun
# ARTIST                Billy Thorpe
# yr_Released                      0
# Name: 183, dtype: object
#
# 184 Song           Fairies Wear Boots
# ARTIST              Black Sabbath
# yr_Released                  1970
# Name: 184, dtype: object
#
# 185 Song           Heaven and Hell
# ARTIST           Black Sabbath
# yr_Released               1980
# Name: 185, dtype: object
#
# 186 Song                Iron Man
# ARTIST         Black Sabbath
# yr_Released             1972
# Name: 186, dtype: object
#
# 187 Song                  N.i.b.
# ARTIST         Black Sabbath
# yr_Released             1970
# Name: 187, dtype: object
#
# 188 Song            Neon Knights
# ARTIST         Black Sabbath
# yr_Released             1980
# Name: 188, dtype: object
#
# 189 Song                Paranoid
# ARTIST         Black Sabbath
# yr_Released             1970
# Name: 189, dtype: object
#
# 190 Song              Sweet Leaf
# ARTIST         Black Sabbath
# yr_Released             1971
# Name: 190, dtype: object
#
# 191 Song              The Wizard
# ARTIST         Black Sabbath
# yr_Released             1970
# Name: 191, dtype: object
#
# 192 Song                War Pigs
# ARTIST         Black Sabbath
# yr_Released             1970
# Name: 192, dtype: object
#
# 193 Song           Highway Song
# ARTIST            Blackfoot
# yr_Released               0
# Name: 193, dtype: object
#
# 194 Song           Train, Train
# ARTIST            Blackfoot
# yr_Released            1979
# Name: 194, dtype: object
#
# 195 Song           Can't Find My Way Home
# ARTIST                    Blind Faith
# yr_Released                      1969
# Name: 195, dtype: object
#
# 196 Song           Presence of the Lord
# ARTIST                  Blind Faith
# yr_Released                    1969
# Name: 196, dtype: object
#
# 197 Song               No Rain
# ARTIST         Blind Melon
# yr_Released           1992
# Name: 197, dtype: object
#
# 198 Song           Presence of the Lord
# ARTIST                  Blind Melon
# yr_Released                       0
# Name: 198, dtype: object
#
# 199 Song           All the Small Things
# ARTIST                    Blink-182
# yr_Released                    1999
# Name: 199, dtype: object
#
# 200 Song           Call Me
# ARTIST         Blondie
# yr_Released       1980
# Name: 200, dtype: object
#
# 201 Song           Heart of Glass
# ARTIST                Blondie
# yr_Released              1978
# Name: 201, dtype: object
#
# 202 Song           One Way Or Another
# ARTIST                    Blondie
# yr_Released                  1978
# Name: 202, dtype: object
#
# 203 Song           (Don't Fear) The Reaper
# ARTIST                Blue Oyster Cult
# yr_Released                       1976
# Name: 203, dtype: object
#
# 204 Song               Bucks Boogie
# ARTIST         Blue Oyster Cult
# yr_Released                   0
# Name: 204, dtype: object
#
# 205 Song            Burnin' for You
# ARTIST         Blue Oyster Cult
# yr_Released                1981
# Name: 205, dtype: object
#
# 206 Song                   Godzilla
# ARTIST         Blue Oyster Cult
# yr_Released                1977
# Name: 206, dtype: object
#
# 207 Song           I Love the Night
# ARTIST         Blue Oyster Cult
# yr_Released                1977
# Name: 207, dtype: object
#
# 208 Song           Summertime Blues
# ARTIST         Blue Oyster Cult
# yr_Released                   0
# Name: 208, dtype: object
#
# 209 Song           Song 2
# ARTIST           Blur
# yr_Released      1997
# Name: 209, dtype: object
#
# 210 Song           Just Like A Woman
# ARTIST                 Bob Dylan
# yr_Released                 1966
# Name: 210, dtype: object
#
# 211 Song           Knockin' On Heaven's Door
# ARTIST                         Bob Dylan
# yr_Released                         1973
# Name: 211, dtype: object
#
# 212 Song           Like a Rolling Stone
# ARTIST                    Bob Dylan
# yr_Released                    1965
# Name: 212, dtype: object
#
# 213 Song           Positively 4th Street
# ARTIST                     Bob Dylan
# yr_Released                     1965
# Name: 213, dtype: object
#
# 214 Song           Subterranean Homesick Blues
# ARTIST                           Bob Dylan
# yr_Released                           1965
# Name: 214, dtype: object
#
# 215 Song           Tangled Up In Blue
# ARTIST                  Bob Dylan
# yr_Released                  1975
# Name: 215, dtype: object
#
# 216 Song               Exodus
# ARTIST         Bob Marley
# yr_Released             0
# Name: 216, dtype: object
#
# 217 Song              Jamming
# ARTIST         Bob Marley
# yr_Released             0
# Name: 217, dtype: object
#
# 218 Song           No Woman, No Cry
# ARTIST               Bob Marley
# yr_Released                1975
# Name: 218, dtype: object
#
# 219 Song             One Love
# ARTIST         Bob Marley
# yr_Released          1977
# Name: 219, dtype: object
#
# 220 Song           Stir It Up
# ARTIST         Bob Marley
# yr_Released             0
# Name: 220, dtype: object
#
# 221 Song           Three Little Birds
# ARTIST                 Bob Marley
# yr_Released                     0
# Name: 221, dtype: object
#
# 222 Song           Against The Wind
# ARTIST                Bob Seger
# yr_Released                1980
# Name: 222, dtype: object
#
# 223 Song           Betty Lou's Gettin' Out Tonigh
# ARTIST                              Bob Seger
# yr_Released                                 0
# Name: 223, dtype: object
#
# 224 Song           Come to Poppa
# ARTIST             Bob Seger
# yr_Released                0
# Name: 224, dtype: object
#
# 225 Song           Feel Like a Number
# ARTIST                  Bob Seger
# yr_Released                     0
# Name: 225, dtype: object
#
# 226 Song           Fire Down Below
# ARTIST               Bob Seger
# yr_Released               1977
# Name: 226, dtype: object
#
# 227 Song           Get Out of Denver
# ARTIST                 Bob Seger
# yr_Released                    0
# Name: 227, dtype: object
#
# 228 Song           Her Strut
# ARTIST         Bob Seger
# yr_Released         1980
# Name: 228, dtype: object
#
# 229 Song           Hollywood Nights
# ARTIST                Bob Seger
# yr_Released                1978
# Name: 229, dtype: object
#
# 230 Song           Horizontal Bop
# ARTIST              Bob Seger
# yr_Released                 0
# Name: 230, dtype: object
#
# 231 Song            Katmandu
# ARTIST         Bob Seger
# yr_Released         1975
# Name: 231, dtype: object
#
# 232 Song           Mainstreet
# ARTIST          Bob Seger
# yr_Released          1977
# Name: 232, dtype: object
#
# 233 Song           Night Moves
# ARTIST           Bob Seger
# yr_Released           1976
# Name: 233, dtype: object
#
# 234 Song           Old Time Rock & Roll
# ARTIST                    Bob Seger
# yr_Released                    1978
# Name: 234, dtype: object
#
# 235 Song           Ramblin' Gamblin' Man
# ARTIST                     Bob Seger
# yr_Released                     1968
# Name: 235, dtype: object
#
# 236 Song           Rock And Roll Never Forgets
# ARTIST                           Bob Seger
# yr_Released                           1977
# Name: 236, dtype: object
#
# 237 Song           Roll Me Away
# ARTIST            Bob Seger
# yr_Released               0
# Name: 237, dtype: object
#
# 238 Song           Still the Same
# ARTIST              Bob Seger
# yr_Released              1978
# Name: 238, dtype: object
#
# 239 Song           Sunspot Baby
# ARTIST            Bob Seger
# yr_Released               0
# Name: 239, dtype: object
#
# 240 Song           The Fire Down Below
# ARTIST                   Bob Seger
# yr_Released                      0
# Name: 240, dtype: object
#
# 241 Song           Travelin' Man
# ARTIST             Bob Seger
# yr_Released                0
# Name: 241, dtype: object
#
# 242 Song           Turn On Your Love Light
# ARTIST                       Bob Seger
# yr_Released                          0
# Name: 242, dtype: object
#
# 243 Song           Turn The Page
# ARTIST             Bob Seger
# yr_Released             1973
# Name: 243, dtype: object
#
# 244 Song           We've Got Tonite
# ARTIST                Bob Seger
# yr_Released                1978
# Name: 244, dtype: object
#
# 245 Song           You'll Accompany Me
# ARTIST                   Bob Seger
# yr_Released                      0
# Name: 245, dtype: object
#
# 246 Song           Hypnotized
# ARTIST          Bob Welch
# yr_Released             0
# Name: 246, dtype: object
#
# 247 Song           Bad Medicine
# ARTIST             Bon Jovi
# yr_Released            1988
# Name: 247, dtype: object
#
# 248 Song           Blaze of Glory
# ARTIST               Bon Jovi
# yr_Released              1990
# Name: 248, dtype: object
#
# 249 Song           Born To Be My Baby
# ARTIST                   Bon Jovi
# yr_Released                  1989
# Name: 249, dtype: object
#
# 250 Song           Lay Your Hands On Me
# ARTIST                     Bon Jovi
# yr_Released                    1988
# Name: 250, dtype: object
#
# 251 Song           Livin' On A Prayer
# ARTIST                   Bon Jovi
# yr_Released                  1986
# Name: 251, dtype: object
#
# 252 Song           Raise Your Hands
# ARTIST                 Bon Jovi
# yr_Released                   0
# Name: 252, dtype: object
#
# 253 Song            Runaway
# ARTIST         Bon Jovi
# yr_Released        1984
# Name: 253, dtype: object
#
# 254 Song           She Don't Know Me
# ARTIST                  Bon Jovi
# yr_Released                    0
# Name: 254, dtype: object
#
# 255 Song           Wanted Dead or Alive
# ARTIST                     Bon Jovi
# yr_Released                    1986
# Name: 255, dtype: object
#
# 256 Song           You Give Love A Bad Name
# ARTIST                         Bon Jovi
# yr_Released                        1986
# Name: 256, dtype: object
#
# 257 Song           Wait For You
# ARTIST               Bonham
# yr_Released               0
# Name: 257, dtype: object
#
# 258 Song                     Green Onions
# ARTIST         Booker T. and the MG's
# yr_Released                      1962
# Name: 258, dtype: object
#
# 259 Song           A Man I'll Never Be
# ARTIST                      Boston
# yr_Released                      0
# Name: 259, dtype: object
#
# 260 Song           Amanda
# ARTIST         Boston
# yr_Released      1986
# Name: 260, dtype: object
#
# 261 Song           Cool The Engines
# ARTIST                   Boston
# yr_Released                   0
# Name: 261, dtype: object
#
# 262 Song           Don't Look Back
# ARTIST                  Boston
# yr_Released               1978
# Name: 262, dtype: object
#
# 263 Song           Feelin' Satisfied
# ARTIST                    Boston
# yr_Released                    0
# Name: 263, dtype: object
#
# 264 Song           Foreplay (Long Time)
# ARTIST                       Boston
# yr_Released                    1976
# Name: 264, dtype: object
#
# 265 Song           Hitch A Ride
# ARTIST               Boston
# yr_Released            1976
# Name: 265, dtype: object
#
# 266 Song           Let Me Take You Home Tonight
# ARTIST                               Boston
# yr_Released                            1976
# Name: 266, dtype: object
#
# 267 Song           More Than a Feeling
# ARTIST                      Boston
# yr_Released                   1976
# Name: 267, dtype: object
#
# 268 Song            Party
# ARTIST         Boston
# yr_Released         0
# Name: 268, dtype: object
#
# 269 Song           Peace of Mind
# ARTIST                Boston
# yr_Released             1976
# Name: 269, dtype: object
#
# 270 Song           Rock & Roll Band
# ARTIST                   Boston
# yr_Released                1976
# Name: 270, dtype: object
#
# 271 Song           Smokin'
# ARTIST          Boston
# yr_Released       1976
# Name: 271, dtype: object
#
# 272 Song           Something About You
# ARTIST                      Boston
# yr_Released                      0
# Name: 272, dtype: object
#
# 273 Song           The Journey/It's Easy
# ARTIST                        Boston
# yr_Released                        0
# Name: 273, dtype: object
#
# 274 Song           Used To Bad News
# ARTIST                   Boston
# yr_Released                   0
# Name: 274, dtype: object
#
# 275 Song           We're Ready
# ARTIST              Boston
# yr_Released              0
# Name: 275, dtype: object
#
# 276 Song           Lido Shuffle
# ARTIST           Boz Scaggs
# yr_Released            1976
# Name: 276, dtype: object
#
# 277 Song              Lowdown
# ARTIST         Boz Scaggs
# yr_Released          1976
# Name: 277, dtype: object
#
# 278 Song                Tarkio Road
# ARTIST         Brewer & Shipley
# yr_Released                   0
# Name: 278, dtype: object
#
# 279 Song                       The Way It Is
# ARTIST         Bruce Hornsby & The Range
# yr_Released                         1986
# Name: 279, dtype: object
#
# 280 Song               Atlantic City
# ARTIST         Bruce Springsteen
# yr_Released                 1982
# Name: 280, dtype: object
#
# 281 Song                 Backstreets
# ARTIST         Bruce Springsteen
# yr_Released                 1975
# Name: 281, dtype: object
#
# 282 Song                    Badlands
# ARTIST         Bruce Springsteen
# yr_Released                 1978
# Name: 282, dtype: object
#
# 283 Song           Blinded By the Light
# ARTIST            Bruce Springsteen
# yr_Released                    1973
# Name: 283, dtype: object
#
# 284 Song           Born In the U.S.A.
# ARTIST          Bruce Springsteen
# yr_Released                  1984
# Name: 284, dtype: object
#
# 285 Song                 Born To Run
# ARTIST         Bruce Springsteen
# yr_Released                 1975
# Name: 285, dtype: object
#
# 286 Song                    Cover Me
# ARTIST         Bruce Springsteen
# yr_Released                 1984
# Name: 286, dtype: object
#
# 287 Song           Dancing In the Dark
# ARTIST           Bruce Springsteen
# yr_Released                   1984
# Name: 287, dtype: object
#
# 288 Song                  Glory Days
# ARTIST         Bruce Springsteen
# yr_Released                 1984
# Name: 288, dtype: object
#
# 289 Song                  Growin' Up
# ARTIST         Bruce Springsteen
# yr_Released                 1973
# Name: 289, dtype: object
#
# 290 Song                Hungry Heart
# ARTIST         Bruce Springsteen
# yr_Released                 1980
# Name: 290, dtype: object
#
# 291 Song                 I'm On Fire
# ARTIST         Bruce Springsteen
# yr_Released                 1984
# Name: 291, dtype: object
#
# 292 Song           It's Hard to Be a Saint in the City
# ARTIST                           Bruce Springsteen
# yr_Released                                   1973
# Name: 292, dtype: object
#
# 293 Song                 Jersey Girl
# ARTIST         Bruce Springsteen
# yr_Released                    0
# Name: 293, dtype: object
#
# 294 Song                  Jungleland
# ARTIST         Bruce Springsteen
# yr_Released                 1975
# Name: 294, dtype: object
#
# 295 Song               Pink Cadillac
# ARTIST         Bruce Springsteen
# yr_Released                 1984
# Name: 295, dtype: object
#
# 296 Song           Prove It All Night
# ARTIST          Bruce Springsteen
# yr_Released                  1978
# Name: 296, dtype: object
#
# 297 Song           Racing in the Streets
# ARTIST             Bruce Springsteen
# yr_Released                     1978
# Name: 297, dtype: object
#
# 298 Song           Rosalita (Come Out Tonight)
# ARTIST                   Bruce Springsteen
# yr_Released                           1973
# Name: 298, dtype: object
#
# 299 Song               She's The One
# ARTIST         Bruce Springsteen
# yr_Released                 1975
# Name: 299, dtype: object
#
# 300 Song           Spirit In The Night
# ARTIST           Bruce Springsteen
# yr_Released                   1973
# Name: 300, dtype: object
#
# 301 Song           Tenth Avenue Freeze-Out
# ARTIST               Bruce Springsteen
# yr_Released                       1975
# Name: 301, dtype: object
#
# 302 Song                Thunder Road
# ARTIST         Bruce Springsteen
# yr_Released                 1975
# Name: 302, dtype: object
#
# 303 Song           Cuts Like a Knife
# ARTIST               Bryan Adams
# yr_Released                 1983
# Name: 303, dtype: object
#
# 304 Song                Heaven
# ARTIST         Bryan Adams
# yr_Released           1984
# Name: 304, dtype: object
#
# 305 Song            Run to You
# ARTIST         Bryan Adams
# yr_Released           1984
# Name: 305, dtype: object
#
# 306 Song              Somebody
# ARTIST         Bryan Adams
# yr_Released           1984
# Name: 306, dtype: object
#
# 307 Song           Summer Of '69
# ARTIST           Bryan Adams
# yr_Released             1984
# Name: 307, dtype: object
#
# 308 Song                Sorry
# ARTIST         Buckcherry
# yr_Released          2007
# Name: 308, dtype: object
#
# 309 Song           For What It's Worth
# ARTIST         Buffalo Springfield
# yr_Released                   1966
# Name: 309, dtype: object
#
# 310 Song                      Mr. Soul
# ARTIST         Buffalo Springfield
# yr_Released                   1967
# Name: 310, dtype: object
#
# 311 Song             Rock & Roll Woman
# ARTIST         Buffalo Springfield
# yr_Released                      0
# Name: 311, dtype: object
#
# 312 Song           Comedown
# ARTIST             Bush
# yr_Released        1994
# Name: 312, dtype: object
#
# 313 Song           Machinehead
# ARTIST                Bush
# yr_Released           1994
# Name: 313, dtype: object
#
# 314 Song           Far Behind
# ARTIST          Candlebox
# yr_Released          1993
# Name: 314, dtype: object
#
# 315 Song           Goin' up the Country
# ARTIST                  Canned Heat
# yr_Released                    1968
# Name: 315, dtype: object
#
# 316 Song           On the Road Again
# ARTIST               Canned Heat
# yr_Released                 1968
# Name: 316, dtype: object
#
# 317 Song           IT'S TOO LATE
# ARTIST           Carole King
# yr_Released             1971
# Name: 317, dtype: object
#
# 318 Song           Oh Very Young
# ARTIST           Cat Stevens
# yr_Released                0
# Name: 318, dtype: object
#
# 319 Song            WILD WORLD
# ARTIST         Cat Stevens
# yr_Released           1971
# Name: 319, dtype: object
#
# 320 Song                     In America
# ARTIST         Charlie Daniels Band
# yr_Released                    1980
# Name: 320, dtype: object
#
# 321 Song           Long Haired Country Boy
# ARTIST            Charlie Daniels Band
# yr_Released                       1975
# Name: 321, dtype: object
#
# 322 Song           The Devil Went Down To Georgia
# ARTIST                   Charlie Daniels Band
# yr_Released                              1979
# Name: 322, dtype: object
#
# 323 Song           The Legend Of Wooley Swamp
# ARTIST               Charlie Daniels Band
# yr_Released                             0
# Name: 323, dtype: object
#
# 324 Song           The South's Gonna Do It Again
# ARTIST                  Charlie Daniels Band
# yr_Released                             1975
# Name: 324, dtype: object
#
# 325 Song                   Uneasy Rider
# ARTIST         Charlie Daniels Band
# yr_Released                    1973
# Name: 325, dtype: object
#
# 326 Song           Ain't That a Shame
# ARTIST                Cheap Trick
# yr_Released                     0
# Name: 326, dtype: object
#
# 327 Song           Dream Police
# ARTIST          Cheap Trick
# yr_Released               0
# Name: 327, dtype: object
#
# 328 Song           I Want You to Want Me
# ARTIST                   Cheap Trick
# yr_Released                     1977
# Name: 328, dtype: object
#
# 329 Song           She's Tight
# ARTIST         Cheap Trick
# yr_Released              0
# Name: 329, dtype: object
#
# 330 Song             Surrender
# ARTIST         Cheap Trick
# yr_Released           1978
# Name: 330, dtype: object
#
# 331 Song           Take Out The Gunman
# ARTIST                    Chevelle
# yr_Released                   2014
# Name: 331, dtype: object
#
# 332 Song           25 Or 6 To 4
# ARTIST              Chicago
# yr_Released            1970
# Name: 332, dtype: object
#
# 333 Song           Beginnings
# ARTIST            Chicago
# yr_Released             0
# Name: 333, dtype: object
#
# 334 Song           Feeling Stronger Every
# ARTIST                        Chicago
# yr_Released                      1973
# Name: 334, dtype: object
#
# 335 Song           I'm a Man
# ARTIST           Chicago
# yr_Released            0
# Name: 335, dtype: object
#
# 336 Song           JUST YOU AND ME
# ARTIST                 Chicago
# yr_Released                  0
# Name: 336, dtype: object
#
# 337 Song           Make Me Smile
# ARTIST               Chicago
# yr_Released             1970
# Name: 337, dtype: object
#
# 338 Song           Questions 67 and 68
# ARTIST                     Chicago
# yr_Released                   1969
# Name: 338, dtype: object
#
# 339 Song           Saturday In the Park
# ARTIST                      Chicago
# yr_Released                    1972
# Name: 339, dtype: object
#
# 340 Song           South California Purples
# ARTIST                          Chicago
# yr_Released                           0
# Name: 340, dtype: object
#
# 341 Song           JOHNNY B. GOODE
# ARTIST             Chuck Berry
# yr_Released               1958
# Name: 341, dtype: object
#
# 342 Song           Coming Home
# ARTIST          Cinderella
# yr_Released           1988
# Name: 342, dtype: object
#
# 343 Song           Don't Know What You Got
# ARTIST                      Cinderella
# yr_Released                       1988
# Name: 343, dtype: object
#
# 344 Song           Gypsy Road
# ARTIST         Cinderella
# yr_Released          1988
# Name: 344, dtype: object
#
# 345 Song           Nobody's Fool
# ARTIST            Cinderella
# yr_Released             1986
# Name: 345, dtype: object
#
# 346 Song           Somebody Save Me
# ARTIST               Cinderella
# yr_Released                1986
# Name: 346, dtype: object
#
# 347 Song           Better Off Without You
# ARTIST                         Clarks
# yr_Released                         0
# Name: 347, dtype: object
#
# 348 Song           Born Too Late
# ARTIST                Clarks
# yr_Released                0
# Name: 348, dtype: object
#
# 349 Song           Cigarette
# ARTIST            Clarks
# yr_Released            0
# Name: 349, dtype: object
#
# 350 Song           Hey You
# ARTIST          Clarks
# yr_Released          0
# Name: 350, dtype: object
#
# 351 Song            Maybe
# ARTIST         Clarks
# yr_Released         0
# Name: 351, dtype: object
#
# 352 Song           Penny On The Floor
# ARTIST                     Clarks
# yr_Released                     0
# Name: 352, dtype: object
#
# 353 Song           The River
# ARTIST            Clarks
# yr_Released            0
# Name: 353, dtype: object
#
# 354 Song                  December
# ARTIST         Collective Soul
# yr_Released                  0
# Name: 354, dtype: object
#
# 355 Song                     Shine
# ARTIST         Collective Soul
# yr_Released               1993
# Name: 355, dtype: object
#
# 356 Song           The World I Know
# ARTIST          Collective Soul
# yr_Released                1995
# Name: 356, dtype: object
#
# 357 Song           Hot Rod Lincoln
# ARTIST          Commander Cody
# yr_Released               1971
# Name: 357, dtype: object
#
# 358 Song           Monkey Bars
# ARTIST         Coney Hatch
# yr_Released              0
# Name: 358, dtype: object
#
# 359 Song                Mr. Jones
# ARTIST         Counting Crows
# yr_Released              1993
# Name: 359, dtype: object
#
# 360 Song               Low
# ARTIST         Cracker
# yr_Released       1993
# Name: 360, dtype: object
#
# 361 Song           Badge
# ARTIST         Cream
# yr_Released     1969
# Name: 361, dtype: object
#
# 362 Song           Born Under A Bad Sign
# ARTIST                         Cream
# yr_Released                        0
# Name: 362, dtype: object
# 363 Song           Crossroads
# ARTIST              Cream
# yr_Released          1968
# Name: 363, dtype: object
#
# 364 Song           I'm So Glad
# ARTIST               Cream
# yr_Released           1966
# Name: 364, dtype: object
#
# 365 Song           Sunshine of Your Love
# ARTIST                         Cream
# yr_Released                     1967
# Name: 365, dtype: object
#
# 366 Song           Tales Of Brave Ulysses
# ARTIST                          Cream
# yr_Released                      1967
# Name: 366, dtype: object
#
# 367 Song           White Room
# ARTIST              Cream
# yr_Released          1968
# Name: 367, dtype: object
#
# 368 Song           Higher
# ARTIST          Creed
# yr_Released      1999
# Name: 368, dtype: object
#
# 369 Song           My Sacrifice
# ARTIST                Creed
# yr_Released               0
# Name: 369, dtype: object
#
# 370 Song           With Arms Wide Open
# ARTIST                       Creed
# yr_Released                   1999
# Name: 370, dtype: object
#
# 371 Song                        Bad Moon Rising
# ARTIST         Creedence Clearwater Revival
# yr_Released                            1969
# Name: 371, dtype: object
#
# 372 Song                      Born On the Bayou
# ARTIST         Creedence Clearwater Revival
# yr_Released                            1969
# Name: 372, dtype: object
#
# 373 Song                              Commotion
# ARTIST         Creedence Clearwater Revival
# yr_Released                               0
# Name: 373, dtype: object
#
# 374 Song                     Down On the Corner
# ARTIST         Creedence Clearwater Revival
# yr_Released                            1969
# Name: 374, dtype: object
#
# 375 Song                          Fortunate Son
# ARTIST         Creedence Clearwater Revival
# yr_Released                            1970
# Name: 375, dtype: object
#
# 376 Song                            Green River
# ARTIST         Creedence Clearwater Revival
# yr_Released                            1969
# Name: 376, dtype: object
#
# 377 Song           Have You Ever Seen the Rain?
# ...
# Name: 2105, dtype: object
#
# 2106 Song           With Or Without You
# ARTIST                          U2
# yr_Released                   1987
# Name: 2106, dtype: object
#
# 2107 Song           Red Red Wine
# ARTIST                 UB40
# yr_Released            1983
# Name: 2107, dtype: object
#
# 2108 Song           Lights Out (Live)
# ARTIST                       UFO
# yr_Released                 1976
# Name: 2108, dtype: object
#
# 2109 Song           Too Hot To Handle
# ARTIST                       UFO
# yr_Released                    0
# Name: 2109, dtype: object
#
# 2110 Song           Easy Livin'
# ARTIST          Uriah Heep
# yr_Released              0
# Name: 2110, dtype: object
#
# 2111 Song             Stealin'
# ARTIST         Uriah Heep
# yr_Released          1973
# Name: 2111, dtype: object
#
# 2112 Song           The Wizard
# ARTIST         Uriah Heep
# yr_Released          1972
# Name: 2112, dtype: object
#
# 2113 Song           (Oh) Pretty Woman
# ARTIST                 Van Halen
# yr_Released                 1982
# Name: 2113, dtype: object
#
# 2114 Song           1984/jump
# ARTIST         Van Halen
# yr_Released         1984
# Name: 2114, dtype: object
#
# 2115 Song           Ain't Talkin' 'bout Love
# ARTIST                        Van Halen
# yr_Released                        1978
# Name: 2115, dtype: object
#
# 2116 Song           And the Cradle Will Rock...
# ARTIST                           Van Halen
# yr_Released                           1980
# Name: 2116, dtype: object
#
# 2117 Song           Atomic Punk
# ARTIST           Van Halen
# yr_Released              0
# Name: 2117, dtype: object
#
# 2118 Song           Beautiful Girls
# ARTIST               Van Halen
# yr_Released               1979
# Name: 2118, dtype: object
#
# 2119 Song           Best Of Both Worlds
# ARTIST                   Van Halen
# yr_Released                      0
# Name: 2119, dtype: object
#
# 2120 Song           Black And Blue
# ARTIST              Van Halen
# yr_Released                 0
# Name: 2120, dtype: object
#
# 2121 Song           Dance the Night Away
# ARTIST                    Van Halen
# yr_Released                    1979
# Name: 2121, dtype: object
#
# 2122 Song           Dancing In the Street
# ARTIST                     Van Halen
# yr_Released                     1982
# Name: 2122, dtype: object
#
# 2123 Song              Dreams
# ARTIST         Van Halen
# yr_Released         1986
# Name: 2123, dtype: object
#
# 2124 Song           Drop Dead Legs
# ARTIST              Van Halen
# yr_Released                 0
# Name: 2124, dtype: object
#
# 2125 Song           Eruption - You Really Got Me
# ARTIST                            Van Halen
# yr_Released                            1978
# Name: 2125, dtype: object
#
# 2126 Song           Everybody Wants Some!!
# ARTIST                      Van Halen
# yr_Released                      1980
# Name: 2126, dtype: object
#
# 2127 Song           Feel Your Love Tonight
# ARTIST                      Van Halen
# yr_Released                         0
# Name: 2127, dtype: object
#
# 2128 Song           Feels So Good
# ARTIST             Van Halen
# yr_Released                0
# Name: 2128, dtype: object
#
# 2129 Song           Finish What Ya Started
# ARTIST                      Van Halen
# yr_Released                         0
# Name: 2129, dtype: object
#
# 2130 Song           Hot for Teacher
# ARTIST               Van Halen
# yr_Released               1984
# Name: 2130, dtype: object
#
# 2131 Song           I'll Wait
# ARTIST         Van Halen
# yr_Released            0
# Name: 2131, dtype: object
#
# 2132 Song           I'm the One
# ARTIST           Van Halen
# yr_Released           1978
# Name: 2132, dtype: object
#
# 2133 Song           Ice Cream Man
# ARTIST             Van Halen
# yr_Released             1978
# Name: 2133, dtype: object
#
# 2134 Song           Intruder/ Pretty Woman
# ARTIST                      Van Halen
# yr_Released                         0
# Name: 2134, dtype: object
#
# 2135 Song           Jamie's Cryin'
# ARTIST              Van Halen
# yr_Released              1978
# Name: 2135, dtype: object
#
# 2136 Song                Jump
# ARTIST         Van Halen
# yr_Released         1984
# Name: 2136, dtype: object
#
# 2137 Song           Little Dreamer
# ARTIST              Van Halen
# yr_Released                 0
# Name: 2137, dtype: object
#
# 2138 Song           Little Guitars
# ARTIST              Van Halen
# yr_Released              1982
# Name: 2138, dtype: object
#
# 2139 Song           Love Walks In
# ARTIST             Van Halen
# yr_Released             1986
# Name: 2139, dtype: object
#
# 2140 Song           Mean Street
# ARTIST           Van Halen
# yr_Released              0
# Name: 2140, dtype: object
#
# 2141 Song              Panama
# ARTIST         Van Halen
# yr_Released         1984
# Name: 2141, dtype: object
#
# 2142 Song           Poundcake
# ARTIST         Van Halen
# yr_Released         1991
# Name: 2142, dtype: object
#
# 2143 Song           PRETTY WOMAN
# ARTIST            Van Halen
# yr_Released               0
# Name: 2143, dtype: object
#
# 2144 Song           Right Now
# ARTIST         Van Halen
# yr_Released         1991
# Name: 2144, dtype: object
#
# 2145 Song           Runaround
# ARTIST         Van Halen
# yr_Released            0
# Name: 2145, dtype: object
#
# 2146 Song           Runnin' with the Devil
# ARTIST                      Van Halen
# yr_Released                      1978
# Name: 2146, dtype: object
#
# 2147 Song           Somebody Get Me A Doctor
# ARTIST                        Van Halen
# yr_Released                           0
# Name: 2147, dtype: object
#
# 2148 Song           Summer Nights
# ARTIST             Van Halen
# yr_Released             1986
# Name: 2148, dtype: object
#
# 2149 Song           Take Your Whiskey Home
# ARTIST                      Van Halen
# yr_Released                         0
# Name: 2149, dtype: object
#
# 2150 Song           Top Jimmy
# ARTIST         Van Halen
# yr_Released            0
# Name: 2150, dtype: object
#
# 2151 Song           Top of the World
# ARTIST                Van Halen
# yr_Released                   0
# Name: 2151, dtype: object
#
# 2152 Song           Unchained
# ARTIST         Van Halen
# yr_Released         1981
# Name: 2152, dtype: object
#
# 2153 Song           When It's Love
# ARTIST              Van Halen
# yr_Released              1988
# Name: 2153, dtype: object
#
# 2154 Song           Where Have All the Good Times Gone!
# ARTIST                                   Van Halen
# yr_Released                                   1982
# Name: 2154, dtype: object
#
# 2155 Song           Why Can't This Be Love
# ARTIST                      Van Halen
# yr_Released                      1986
# Name: 2155, dtype: object
#
# 2156 Song           You Really Got Me
# ARTIST                 Van Halen
# yr_Released                 1978
# Name: 2156, dtype: object
#
# 2157 Song           And It Stoned Me
# ARTIST             Van Morrison
# yr_Released                   0
# Name: 2157, dtype: object
#
# 2158 Song             BLUE MONEY
# ARTIST         Van Morrison
# yr_Released               0
# Name: 2158, dtype: object
#
# 2159 Song           Brown Eyed Girl
# ARTIST            Van Morrison
# yr_Released               1967
# Name: 2159, dtype: object
#
# 2160 Song             CRAZY LOVE
# ARTIST         Van Morrison
# yr_Released            1970
# Name: 2160, dtype: object
#
# 2161 Song                 Domino
# ARTIST         Van Morrison
# yr_Released            1970
# Name: 2161, dtype: object
#
# 2162 Song                 Gloria
# ARTIST         Van Morrison
# yr_Released               0
# Name: 2162, dtype: object
#
# 2163 Song           Into The Mystic
# ARTIST            Van Morrison
# yr_Released               1970
# Name: 2163, dtype: object
#
# 2164 Song           Jackie Wilson Said
# ARTIST               Van Morrison
# yr_Released                     0
# Name: 2164, dtype: object
#
# 2165 Song              Moondance
# ARTIST         Van Morrison
# yr_Released            1970
# Name: 2165, dtype: object
#
# 2166 Song             Wild Night
# ARTIST         Van Morrison
# yr_Released            1971
# Name: 2166, dtype: object
#
# 2167 Song           Blister In the Sun
# ARTIST             Violent Femmes
# yr_Released                  1982
# Name: 2167, dtype: object
#
# 2168 Song           Edge of a Broken Heart
# ARTIST                          Vixen
# yr_Released                         0
# Name: 2168, dtype: object
#
# 2169 Song           Low Rider
# ARTIST               War
# yr_Released         1975
# Name: 2169, dtype: object
#
# 2170 Song           Spill the Wine
# ARTIST                    War
# yr_Released              1970
# Name: 2170, dtype: object
#
# 2171 Song           The Cisco Kid
# ARTIST                   War
# yr_Released             1972
# Name: 2171, dtype: object
#
# 2172 Song           Why Can't We Be Friends
# ARTIST                             War
# yr_Released                       1975
# Name: 2172, dtype: object
#
# 2173 Song           Cherry Pie
# ARTIST            Warrant
# yr_Released          1990
# Name: 2173, dtype: object
#
# 2174 Song           Uncle Tom's Cabin
# ARTIST                   Warrant
# yr_Released                    0
# Name: 2174, dtype: object
#
# 2175 Song           Lawyers, Guns and Money
# ARTIST                    Warren Zevon
# yr_Released                       1978
# Name: 2175, dtype: object
#
# 2176 Song           Werewolves of London
# ARTIST                 Warren Zevon
# yr_Released                    1978
# Name: 2176, dtype: object
#
# 2177 Song           Buddy Holly
# ARTIST              Weezer
# yr_Released           1994
# Name: 2177, dtype: object
#
# 2178 Song           Street Corner Serenade
# ARTIST                     Wet Willie
# yr_Released                         0
# Name: 2178, dtype: object
#
# 2179 Song                 Wait
# ARTIST         White Lion
# yr_Released             0
# Name: 2179, dtype: object
#
# 2180 Song           Fool for Your Loving
# ARTIST                   Whitesnake
# yr_Released                    1980
# Name: 2180, dtype: object
#
# 2181 Song           Here I Go Again
# ARTIST              Whitesnake
# yr_Released               1987
# Name: 2181, dtype: object
#
# 2182 Song           Is This Love
# ARTIST           Whitesnake
# yr_Released            1987
# Name: 2182, dtype: object
#
# 2183 Song           Slide It In
# ARTIST          Whitesnake
# yr_Released           1984
# Name: 2183, dtype: object
#
# 2184 Song           Slow An' Easy
# ARTIST            Whitesnake
# yr_Released                0
# Name: 2184, dtype: object
#
# 2185 Song           Still of the Night
# ARTIST                 Whitesnake
# yr_Released                     0
# Name: 2185, dtype: object
#
# 2186 Song           Who Are You?
# ARTIST              Why Not
# yr_Released               0
# Name: 2186, dtype: object
#
# 2187 Song           PLAY THAT FUNKY MUSIC
# ARTIST                   Wild Cherry
# yr_Released                     1976
# Name: 2187, dtype: object
#
# 2188 Song           Night Moves
# ARTIST            Wildlife
# yr_Released              0
# Name: 2188, dtype: object
#
# 2189 Song           We've Got Tonight
# ARTIST                  Wildlife
# yr_Released                    0
# Name: 2189, dtype: object
#
# 2190 Song           Can't Get Enough
# ARTIST                   Winger
# yr_Released                   0
# Name: 2190, dtype: object
#
# 2191 Song           Headed For A Heartbreak
# ARTIST                          Winger
# yr_Released                          0
# Name: 2191, dtype: object
#
# 2192 Song           Seventeen
# ARTIST            Winger
# yr_Released            0
# Name: 2192, dtype: object
#
# 2193 Song             Persephone
# ARTIST         Wishbone Ash
# yr_Released            1980
# Name: 2193, dtype: object
#
# 2194 Song           Summertime Girls
# ARTIST                      Y&T
# yr_Released                   0
# Name: 2194, dtype: object
#
# 2195 Song           Changes
# ARTIST             Yes
# yr_Released       1983
# Name: 2195, dtype: object
#
# 2196 Song           I've Seen All Good People
# ARTIST                               Yes
# yr_Released                         1971
# Name: 2196, dtype: object
#
# 2197 Song           It Can Happen
# ARTIST                   Yes
# yr_Released             1983
# Name: 2197, dtype: object
#
# 2198 Song           Leave It
# ARTIST              Yes
# yr_Released        1983
# Name: 2198, dtype: object
#
# 2199 Song           Long Distance Runaround
# ARTIST                             Yes
# yr_Released                       1972
# Name: 2199, dtype: object
#
# 2200 Song           Owner of a Lonely Heart
# ARTIST                             Yes
# yr_Released                       1983
# Name: 2200, dtype: object
#
# 2201 Song           Roundabout
# ARTIST                Yes
# yr_Released          1971
# Name: 2201, dtype: object
#
# 2202 Song           Starship Trooper
# ARTIST                      Yes
# yr_Released                1971
# Name: 2202, dtype: object
#
# 2203 Song           Wonderous Stories
# ARTIST                       Yes
# yr_Released                    0
# Name: 2203, dtype: object
#
# 2204 Song           Yours Is No Disgrace
# ARTIST                          Yes
# yr_Released                    1971
# Name: 2204, dtype: object
#
# 2205 Song           Tell Me What You Want
# ARTIST                         Zebra
# yr_Released                        0
# Name: 2205, dtype: object
#
# 2206 Song           Who's Behind The Door
# ARTIST                         Zebra
# yr_Released                        0
# Name: 2206, dtype: object
#
# 2207 Song           Time of the Season
# ARTIST                    Zombies
# yr_Released                  1968
# Name: 2207, dtype: object
#
# 2208 Song           A Fool for Your Stockings
# ARTIST                            ZZ Top
# yr_Released                            0
# Name: 2208, dtype: object
#
# 2209 Song           Arrested For Driving While Blind
# ARTIST                                   ZZ Top
# yr_Released                                1976
# Name: 2209, dtype: object
#
# 2210 Song           Beer Drinkers & Hell Raisers
# ARTIST                               ZZ Top
# yr_Released                            1973
# Name: 2210, dtype: object
#
# 2211 Song           Cheap Sunglasses
# ARTIST                   ZZ Top
# yr_Released                1980
# Name: 2211, dtype: object
#
# 2212 Song           Gimme All Your Lovin
# ARTIST                       ZZ Top
# yr_Released                    1983
# Name: 2212, dtype: object
#
# 2213 Song           Got Me Under Pressure
# ARTIST                        ZZ Top
# yr_Released                     1983
# Name: 2213, dtype: object
#
# 2214 Song           Heard It On the X
# ARTIST                    ZZ Top
# yr_Released                 1975
# Name: 2214, dtype: object
#
# 2215 Song           I Thank You
# ARTIST              ZZ Top
# yr_Released              0
# Name: 2215, dtype: object
#
# 2216 Song           I'm Bad, I'm Nationwide
# ARTIST                          ZZ Top
# yr_Released                          0
# Name: 2216, dtype: object
#
# 2217 Song           Jesus Just Left Chicago
# ARTIST                          ZZ Top
# yr_Released                       1973
# Name: 2217, dtype: object
#
# 2218 Song           Just Got Paid
# ARTIST                ZZ Top
# yr_Released                0
# Name: 2218, dtype: object
#
# 2219 Song           La Grange
# ARTIST            ZZ Top
# yr_Released         1973
# Name: 2219, dtype: object
#
# 2220 Song             Legs
# ARTIST         ZZ Top
# yr_Released      1983
# Name: 2220, dtype: object
#
# 2221 Song           My Head's In Mississippi
# ARTIST                           ZZ Top
# yr_Released                           0
# Name: 2221, dtype: object
#
# 2222 Song           Party On The Patio
# ARTIST                     ZZ Top
# yr_Released                     0
# Name: 2222, dtype: object
#
# 2223 Song           Pearl Necklace
# ARTIST                 ZZ Top
# yr_Released              1981
# Name: 2223, dtype: object
#
# 2224 Song           Sharp Dressed Man
# ARTIST                    ZZ Top
# yr_Released                 1983
# Name: 2224, dtype: object
#
# 2225 Song           She Loves My Automobile
# ARTIST                          ZZ Top
# yr_Released                          0
# Name: 2225, dtype: object
#
# 2226 Song           Tube Snake Boogie
# ARTIST                    ZZ Top
# yr_Released                 1981
# Name: 2226, dtype: object
#
# 2227 Song             Tush
# ARTIST         ZZ Top
# yr_Released      1975
# Name: 2227, dtype: object
#
# 2228 Song           TV Dinners
# ARTIST             ZZ Top
# yr_Released          1983
# Name: 2228, dtype: object
#
# 2229 Song           WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO
# ARTIST                                              ZZ Top
# yr_Released                                           1973
# Name: 2229, dtype: object

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.

# %%
# A:

# %% [markdown]
# You'll notice that there will be a final output Series of `None` values. The `.apply()` function, if a return value is not specified, will return a Series of `None` values (similar to how the default return for Python functions is `None` when a return statement is not specified).

# %% [markdown]
# ### 9. Write a function that converts cells in a DataFrame to float and otherwise replaces them with `np.nan`.
#
# If applied to our data, it would keep only the numeric information and otherwise input null values.
#
# Recall that the try-except syntax in Python is a great way to try something and take another action if the initial step fails:
#
# ```python
# try:
#     Perform some action.
# except:
#    Perform some other action if the first failed with an error.
# ```
#
# #### 9.A Write the function that takes a column and converts all of its values to float if possible and `np.nan` otherwise. The return value should be the converted Series.

# %%
# A:
df1 = df_new.apply(pd.to_numeric, args=('coerce',))

# %% [markdown]
# #### 9.B Try your function out on the rock song data and ensure the output is what you expected.

# %%
# A:

# %% [markdown]
# #### 9.C Describe the new float-only DataFrame.

# %%
# A:
df1.describe
# Out:
# <bound method NDFrame.describe of       Song  ARTIST  yr_Released
# 0      NaN     NaN         1982
# 1      NaN     NaN            0
# 2      NaN     NaN         1981
# 3      NaN     NaN         1980
# 4      NaN     NaN         1975
# ...    ...     ...          ...
# 2225   NaN     NaN            0
# 2226   NaN     NaN         1981
# 2227   NaN     NaN         1975
# 2228   NaN     NaN         1983
# 2229   NaN     NaN         1973
#
# [2230 rows x 3 columns]>
